# %%
import os, sys
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
project = os.path.dirname(os.getcwd())
project
# Out:
# 'c:\\Users\\Mónica Emmanuelle\\Documents\\Code\\GAN Builder'

# %%
models = os.path.join(project, "Models")
folder = os.path.join(models, "flickr")
train = os.path.join(folder, "train")
target = os.path.join(folder, "target")
files = os.listdir(target)

# %%
len(files)
# Out:
# 31784

# %%
files[31783]
# Out:
# 'results.csv'

# %%
my_file = os.path.join(target, files[2])
image = Image.open(my_file)
with sns.axes_style("white"):
    g = plt.subplots(figsize=(6, 12))
    g = plt.imshow(image)

# %%
for i in range(len(files)):
    my_file = os.path.join(target, files[i])
    image = Image.open(my_file)
    image2 = image.convert('L')
    image2.save(os.path.join(train, files[i]))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-24-017a27b4052d> in <module>
#       1 for i in range(len(files)):
#       2     my_file = os.path.join(target, files[i])
# ----> 3     image = Image.open(my_file)
#       4     image2 = image.convert('L')
#       5     image2.save(os.path.join(train, files[i]))
#
# C:\Anaconda\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2941     for message in accept_warnings:
#    2942         warnings.warn(message)
# -> 2943     raise UnidentifiedImageError(
#    2944         "cannot identify image file %r" % (filename if filename else fp)
#    2945     )
#
# UnidentifiedImageError: cannot identify image file 'c:\\Users\\Mónica Emmanuelle\\Documents\\Code\\GAN Builder\\Models\\flickr\\target\\results.csv'

# %%
image2 = image.convert('L')

# %%
image2.save(os.path.join(train, "gray.jpg"))
